# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import class data
neg_class = pd.read_csv('/Volumes/Johnathan/1_Metabolomic/1_Data/20231204_Cell-Death_Metabolite_Sup_HMDB/Processed_Data/neg_HMDB_class.csv')
pos_class = pd.read_csv('/Volumes/Johnathan/1_Metabolomic/1_Data/20231204_Cell-Death_Metabolite_Sup_HMDB/Processed_Data/pos_HMDB_class.csv')

# import identification data
neg_iden = pd.read_csv('/Volumes/Johnathan/1_Metabolomic/1_Data/20231204_Cell-Death_Metabolite_Sup_HMDB/Processed_Data/neg_iden_multi.csv')
pos_iden = pd.read_csv('/Volumes/Johnathan/1_Metabolomic/1_Data/20231204_Cell-Death_Metabolite_Sup_HMDB/Processed_Data/pos_iden_multi.csv')

# %%
# remove Link, Adducts columns in iden data
neg_iden = neg_iden.drop(['Link', 'Adducts'], axis=1)
pos_iden = pos_iden.drop(['Link', 'Adducts'], axis=1)

# %%
# rename the column name in iden data to match the class data
neg_iden = neg_iden.rename(columns = {"Compound ID" : "HMDB_ID"})
pos_iden = pos_iden.rename(columns = {"Compound ID" : "HMDB_ID"})

# %%
neg_merge = neg_iden.merge(neg_class, on = "HMDB_ID")
pos_merge = pos_iden.merge(pos_class, on = "HMDB_ID")

# %%
neg_class
# Out:
#           HMDB_ID                      common_name                   class  \
# 0     HMDB0013406                       PC(O-36:0)  Glycerophospholipids
# 1     HMDB0013417                  PC(O-18:0/18:0)  Glycerophospholipids
# 2     HMDB0004844     Ganglioside GM3 (d18:1/16:0)         Sphingolipids
# 3     HMDB0117181    CL(8:0/8:0/16:0/18:2(9Z,11Z))  Glycerophospholipids
# 4     HMDB0117202  CL(8:0/8:0/i-16:0/18:2(9Z,11Z))  Glycerophospholipids
# ...           ...                              ...                     ...
# 4566  HMDB0303760              2-Carboxyarabinitol           Fatty Acyls
# 4567  HMDB0038361             (-)-Epigallocatechin            Flavonoids
# 4568  HMDB0038365                (+)-Gallocatechin            Flavonoids
# 4569  HMDB0302404                  4-Gallocatechol            Flavonoids
# 4570  HMDB0303660                    Leucocyanidin            Flavonoids
#
#                                      subclass
# ...

# %%
# Out:
#               Compound      HMDB_ID  Score  Mass Error (ppm)          m/z  \
# 0       1.91_775.6383n  HMDB0013406   36.6         -9.315473   386.811856
# 1       1.91_775.6383n  HMDB0013417   36.6         -9.315473   386.811856
# 2      4.95_1152.7123n  HMDB0004844   41.2         -0.754983  1151.713444
# 3      4.95_1152.7123n  HMDB0117181   38.9         -8.273673  1151.713444
# 4      4.95_1152.7123n  HMDB0117202   38.9         -8.273673  1151.713444
# ...                ...          ...    ...               ...          ...
# 4811  0.53_195.0510m/z  HMDB0303760   43.2         -0.250032   195.050977
# 4812  0.51_305.0671m/z  HMDB0038361   29.5          1.447609   305.067119
# 4813  0.51_305.0671m/z  HMDB0038365   29.5          1.447609   305.067119
# 4814  0.51_305.0671m/z  HMDB0302404   29.5          1.447609   305.067119
# 4815  0.51_305.0671m/z  HMDB0303660   29.5          1.447609   305.067119
#
#       Retention time (min)                      common_name  \
# ...

# %%
# multi-layer
neg_iden = neg_iden.set_index(['Compound', 'Compound ID'])
pos_iden = pos_iden.set_index(['Compound', 'Compound ID'])
